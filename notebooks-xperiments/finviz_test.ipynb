# %%
from typing import Dict, List
from finvizfinance.screener.overview import Overview

# %%
filters = {'Index': 'S&P 500', 'Price': 'Over $5', 'Market Cap.': '+Mid (over $2bln)', 'Average Volume': 'Over 500K', 'Country': 'USA', 'P/E': 'Over 20', 'Beta': 'Over 1'}

# %%
overView = Overview()
overView.set_filter(filters_dict= filters)
screen_data = overView.screener_view()
# Out:
# [Info] loading page [##########################----] 7/8

# %%
stocks_of_interest = screen_data[screen_data['Market Cap'] <= 8e10]

# %%
stocks_of_interest.__len__()
# Out:
# 99
